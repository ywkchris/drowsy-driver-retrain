jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2229.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/144.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2550.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1030.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1766.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1008.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2032.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/964.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2540.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2581.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1464.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/522.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/437.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2223.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2290.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2009.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2356.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2463.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1899.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/851.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/733.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1073.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/782.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2371.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/231.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2154.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1356.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2604.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1500.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1176.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2254.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/201.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/725.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2246.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/612.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/547.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/93.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/983.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2519.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1852.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1653.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2583.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1246.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2358.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/689.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1357.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2069.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2124.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1537.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2062.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1864.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/175.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1333.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1120.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2432.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/607.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/316.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/226.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2484.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1509.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2287.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2467.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1768.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1111.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1891.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1334.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/962.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/78.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2250.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1966.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1866.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1576.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1989.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/433.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/899.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1542.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1248.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/648.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2410.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2158.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/640.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1647.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1046.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2121.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/542.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1652.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1937.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/505.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2549.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2220.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2572.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2074.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/483.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/647.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1689.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1322.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2299.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2586.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/315.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1061.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2313.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/987.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/218.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/635.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/213.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2198.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/431.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1851.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1021.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1538.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2461.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2151.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/2092.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/25.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/1201.jpg
# /kaggle/input/yawn-eye-dataset-new/dataset_new/train/no_yawn/147.jpg
# /kaggle/input/drowsy-model-v2/drowsy-v2.pth

# %%
import torch.nn as nn
class DrowsinessDetector(nn.Module):
    def __init__(self):
        super(DrowsinessDetector, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(64*56*56,128)
        self.fc2 = nn.Linear(128,2)
        self.dropout = nn.Dropout(p=0.5)
        
    def forward(self, x):
        x = self.conv1(x)
        x = nn.ReLU()(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = nn.ReLU()(x)
        x = self.pool(x)
        x = x.view(-1, 64*56*56)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
import torch

# Define the path to your saved model file
model_path = '/kaggle/input/drowsy-model-v1/drowsy_model.pth'

# Load the saved model
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

model = DrowsinessDetector()
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# DrowsinessDetector(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=200704, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# Define the transforms to be applied to each image
test_transforms = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load the test dataset from the new directory structure
test_dataset = ImageFolder('/kaggle/input/yawn-eye-dataset-new/dataset_new/test', transform=test_transforms)

# Class labels for the new dataset
class_labels = ['Non Drowsy', 'Drowsy']

# Create a dictionary to map the new class labels to the original class labels
label_map = {
    0: {'Open', 'no_yawn'},
    1: {'Closed', 'yawn'}
}

# Create a new dataset with the updated class labels
new_test_dataset = []
for image, label in test_dataset:
    new_label = None
    for key, value in label_map.items():
        if test_dataset.classes[label] in value:
            new_label = key
            break
    new_test_dataset.append((image, new_label))

# Define a dataloader to load the new test dataset
batch_size = 32
test_dataloader = torch.utils.data.DataLoader(new_test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Evaluate the model on the test dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print('Accuracy of the model on the test dataset: {:.2f}%'.format(accuracy))
# Out:
# Accuracy of the model on the test dataset: 49.42%

# %% [markdown]
# Re-Train the model

# %%
# Define the transforms to be applied to each image
dataset_transforms = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load the test dataset from the new directory structure
train_dataset = ImageFolder('/kaggle/input/yawn-eye-dataset-new/dataset_new/train', transform=test_transforms)

# Class labels for the new dataset
class_labels = ['Non Drowsy', 'Drowsy']

# Create a dictionary to map the new class labels to the original class labels
label_map = {
    0: {'Open', 'no_yawn'},
    1: {'Closed', 'yawn'}
}

# Create a new dataset with the updated class labels
new_train_dataset = []
for image, label in train_dataset:
    new_label = None
    for key, value in label_map.items():
        if train_dataset.classes[label] in value:
            new_label = key
            break
    new_train_dataset.append((image, new_label))

# Split the data into training and validation sets
torch.manual_seed(42)
train_size = int(0.8*len(new_train_dataset))
val_size = len(new_train_dataset)- train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    new_train_dataset, [train_size, val_size])

    
# Define a dataloader to load the new train dataset
batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
from torchvision.transforms import transforms
from torchvision.datasets import ImageFolder

# Initalize the model
model = DrowsinessDetector()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Train the model on GPU

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

# Move the model to the device
model = model.to(device)


num_epochs = 40
best_acc = 0.0

# Train phase
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch + 1, num_epochs))
    print('-' * 10)

    model.train()  # set model to training mode

    running_loss = 0.0
    running_corrects = 0
    for inputs, labels in train_loader:
        inputs = inputs.to(device)  # move data to device
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = running_corrects.double() / len(train_loader.dataset)
    print('Train Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))

    # Evaluation phase
    model.eval()  # set model to evaluation mode
    running_loss = 0.0
    running_corrects = 0
    for inputs, labels in val_loader:
        inputs = inputs.to(device)  # move data to device
        labels = labels.to(device)

        with torch.no_grad():
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_acc = running_corrects.double() / len(val_loader.dataset)
    print('Val Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
    
    # Check if this is the best model so far
    if epoch_acc > best_acc:
        best_acc = epoch_acc
        best_model_wts = model.state_dict()

print('Training complete. Best validation accuracy: {:.4f}'.format(best_acc))
model.load_state_dict(best_model_wts)
# Out:
# Using device: cuda
# Epoch 1/40
# ----------
# Train Loss: 0.9013 Acc: 0.5773
# Val Loss: 0.6069 Acc: 0.6680
# Epoch 2/40
# ----------
# Train Loss: 0.5329 Acc: 0.7202
# Val Loss: 0.4833 Acc: 0.7368
# Epoch 3/40
# ----------
# Train Loss: 0.4408 Acc: 0.7775
# Val Loss: 0.4095 Acc: 0.7874
# Epoch 4/40
# ----------
# Train Loss: 0.3781 Acc: 0.8099
# Val Loss: 0.3827 Acc: 0.8117
# Epoch 5/40
# ----------
# Train Loss: 0.3401 Acc: 0.8459
# Val Loss: 0.4137 Acc: 0.8036
# Epoch 6/40
# ----------
# Train Loss: 0.3141 Acc: 0.8520
# Val Loss: 0.3555 Acc: 0.8360
# Epoch 7/40
# ----------
# Train Loss: 0.2745 Acc: 0.8789
# Val Loss: 0.2798 Acc: 0.8806
# Epoch 8/40
# ----------
# Train Loss: 0.2130 Acc: 0.9103
# Val Loss: 0.2426 Acc: 0.8846
# Epoch 9/40
# ----------
# Train Loss: 0.1679 Acc: 0.9311
# Val Loss: 0.2473 Acc: 0.9028
# Epoch 10/40
# ----------
# Train Loss: 0.1366 Acc: 0.9463
# Val Loss: 0.2240 Acc: 0.9089
# Epoch 11/40
# ----------
# Train Loss: 0.1135 Acc: 0.9539
# Val Loss: 0.3594 Acc: 0.8765
# Epoch 12/40
# ----------
# Train Loss: 0.1228 Acc: 0.9508
# Val Loss: 0.2256 Acc: 0.9109
# Epoch 13/40
# ----------
# Train Loss: 0.0745 Acc: 0.9757
# Val Loss: 0.2124 Acc: 0.9170
# Epoch 14/40
# ----------
# Train Loss: 0.0691 Acc: 0.9752
# Val Loss: 0.3000 Acc: 0.9049
# Epoch 15/40
# ----------
# Train Loss: 0.0700 Acc: 0.9721
# Val Loss: 0.2527 Acc: 0.9028
# Epoch 16/40
# ----------
# Train Loss: 0.0864 Acc: 0.9676
# Val Loss: 0.1794 Acc: 0.9291
# Epoch 17/40
# ----------
# Train Loss: 0.0592 Acc: 0.9757
# Val Loss: 0.2215 Acc: 0.9190
# Epoch 18/40
# ----------
# Train Loss: 0.0749 Acc: 0.9731
# Val Loss: 0.2174 Acc: 0.9211
# Epoch 19/40
# ----------
# Train Loss: 0.0964 Acc: 0.9640
# Val Loss: 0.2362 Acc: 0.9231
# Epoch 20/40
# ----------
# Train Loss: 0.0640 Acc: 0.9752
# Val Loss: 0.2410 Acc: 0.9130
# Epoch 21/40
# ----------
# Train Loss: 0.0646 Acc: 0.9731
# Val Loss: 0.3090 Acc: 0.8826
# Epoch 22/40
# ----------
# Train Loss: 0.0611 Acc: 0.9802
# Val Loss: 0.1894 Acc: 0.9231
# Epoch 23/40
# ----------
# Train Loss: 0.0429 Acc: 0.9838
# Val Loss: 0.2604 Acc: 0.9251
# Epoch 24/40
# ----------
# Train Loss: 0.0473 Acc: 0.9802
# Val Loss: 0.2628 Acc: 0.8988
# Epoch 25/40
# ----------
# Train Loss: 0.0460 Acc: 0.9858
# Val Loss: 0.4163 Acc: 0.8988
# Epoch 26/40
# ----------
# Train Loss: 0.0544 Acc: 0.9787
# Val Loss: 0.2377 Acc: 0.9251
# Epoch 27/40
# ----------
# Train Loss: 0.0344 Acc: 0.9878
# Val Loss: 0.3449 Acc: 0.8988
# Epoch 28/40
# ----------
# Train Loss: 0.0426 Acc: 0.9848
# Val Loss: 0.1940 Acc: 0.9393
# Epoch 29/40
# ----------
# Train Loss: 0.0333 Acc: 0.9868
# Val Loss: 0.2333 Acc: 0.9251
# Epoch 30/40
# ----------
# Train Loss: 0.0296 Acc: 0.9909
# Val Loss: 0.2442 Acc: 0.9150
# Epoch 31/40
# ----------
# Train Loss: 0.0341 Acc: 0.9899
# Val Loss: 0.3967 Acc: 0.9089
# Epoch 32/40
# ----------
# Train Loss: 0.0384 Acc: 0.9843
# Val Loss: 0.2938 Acc: 0.9130
# Epoch 33/40
# ----------
# Train Loss: 0.0453 Acc: 0.9843
# Val Loss: 0.3757 Acc: 0.8968
# Epoch 34/40
# ----------
# Train Loss: 0.0307 Acc: 0.9858
# Val Loss: 0.3142 Acc: 0.9170
# Epoch 35/40
# ----------
# Train Loss: 0.0445 Acc: 0.9833
# Val Loss: 0.3344 Acc: 0.9109
# Epoch 36/40
# ----------
# Train Loss: 0.0269 Acc: 0.9899
# Val Loss: 0.4067 Acc: 0.9130
# Epoch 37/40
# ----------
# Train Loss: 0.0431 Acc: 0.9848
# Val Loss: 0.4086 Acc: 0.9109
# Epoch 38/40
# ----------
# Train Loss: 0.0487 Acc: 0.9812
# Val Loss: 0.3473 Acc: 0.9190
# Epoch 39/40
# ----------
# Train Loss: 0.0219 Acc: 0.9919
# Val Loss: 0.3308 Acc: 0.9211
# Epoch 40/40
# ----------
# Train Loss: 0.0315 Acc: 0.9914
# Val Loss: 0.2934 Acc: 0.9332
# Training complete. Best validation accuracy: 0.9393
# <All keys matched successfully>

# %%
# Evaluate the model on the test dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print('Accuracy of the model on the test dataset: {:.2f}%'.format(accuracy))
# Out:
# Accuracy of the model on the test dataset: 94.92%

# %%
torch.save(model.state_dict(), '/kaggle/working/drowsy-v2.pth')
